# %%
from scapy.all import *
# Out:
# WARNING: No IPv4 address found on anpi1 !
# WARNING: No IPv4 address found on anpi2 !
# WARNING: more No IPv4 address found on anpi0 !

# %%
pachet = IP()/TCP()
Ether()/pachet
# Out:
# <Ether  type=IPv4 |<IP  frag=0 proto=tcp |<TCP  |>>>

# %%
import pcapkit

# %%
plist = pcapkit.extract(fin='data.pcap', fout='data.json', format='json', verbose=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plist = pcapkit.extract(fin='data.pcap', fout='data.json', format='json', verbose=True)
#
# File ~/Documents/Python/Prosys/cap_ua/venv/lib/python3.10/site-packages/pcapkit/interface/core.py:122, in extract(fin, fout, format, auto, extension, store, files, nofile, verbose, engine, layer, protocol, reassembly, reasm_strict, reasm_store, trace, trace_fout, trace_format, trace_byteorder, trace_nanosecond, ip, ipv4, ipv6, tcp, buffer_size, buffer_save, buffer_path, no_eof)
#     119 if isinstance(layer, type) and issubclass(layer, Protocol):
#     120     layer = (layer.__layer__ or 'none').lower()  # type: ignore[assignment]
# --> 122 return Extractor(fin=fin, fout=fout, format=format,
#     123                  store=store, files=files, nofile=nofile,
# ...
